# %%
from docx import Document
import pandas as pd
import numpy as np
import re
import spacy as sp
import nltk
from nltk.stem.snowball import DanishStemmer
import lemmy
# Out:
# /var/folders/_v/swcgdh2j22n2qvz2080yh82c0000gn/T/ipykernel_9560/3002816583.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def read_docx(file_path):
    doc = Document(file_path)
    text = []
    for paragraph in doc.paragraphs:
        text.append(paragraph.text)
    return ' '.join(text)

# %%
# Path to your .docx file
docx_file_path = '/Users/majastyrkandersen/Desktop/bispebjerg/interviews_merged.docx'

# Read the content of the .docx file
document_text = read_docx(docx_file_path)

# %%
# To lower case
lower_cased = document_text.lower()

# %%
# Remove punctuation
pattern = r'[^\w\s]'
cleaned = re.sub(pattern, '', lower_cased)

# %%
# Remove stopwords using spaCy

nlp = sp.load("da_core_news_sm")

# %%
# Rename un-tokenized data
text = cleaned

# Process the text data
doc = nlp(text)

# %%
# Remove stopwords

filtered_tokens = [token.text for token in doc if not token.is_stop]

# %%
# Remove names Oliver, Arthur, Sonja, and Charlotte
names = ["oliver", "sonja", "arthuer", "charlotte"]

tokens_without_names = list(filter(lambda x: x not in names, filtered_tokens))

# %%
# Normalizing the text (stemming and lemmatization) using NLTK

stemmer = DanishStemmer()
stemmed_tokens = [stemmer.stem(token) for token in tokens_without_names]

# %%
print(stemmed_tokens)
# Out:
# ['regn', 'tag', 'cirka', '40', 'minut', 'plus', 'minus', 'afhæng', 'får', 'fyld', 'opfølg', 'spørgsmål', 'ting', 'bund', 'grund', 'bar', 'godt', 'hør', 'dit', 'arbejd', 'kommunik', 'patient', 'start', 'godt', 'hør', 'fortæl', 'fik', 'radiograf', 'arthur', 'jam', 'hed', 'arthur', '32', 'gang', '24', '23', 'vidst', 'helt', 'arbejd', 'haft', 'lyst', 'arbejd', 'mennesk', 'sid', 'kontor', 'snak', 'patient', 'gaml', 'mennesk', 'bar', 'kombination', 'samtid', 'gad', 'sygeplejersk', 'teknologisk', 'comput', 'åbent', 'hus', 'uddan', 'tænk', 'tja', 'godt', 'fremtid', 'prøved', 'kend', 'når', 'find', 'dit', 'hul', 'samfund', 'passed', 'bar', 'person', 'teknologisk', 'scanning', 'spænd', 'samtid', 'patient', 'sin', 'histori', 'tro', 'ensart', 'arbejd', 'patient', 'anderled', 'ensart', 'sur', 'glad', 'bar', 'normal', 'fik', 'tænk', 'okay', 'lav', 'typ', 'arbejd', 'udfordring', 'radiograf', 'god', 'oplev', 'selvfølg', 'lang', 'tid', 'radiograf', 'arthur', '6', 'år', 'radiograf', 'dit', 'arbejdsområd', 'arthur', 'hed', 'mrsuperbrug', 'arbejd', 'primært', 'mrscan', 'udlånt', 'sted', 'behov', 'uddan', 'hel', 'specialområd', 'mr', 'prøv', 'beskriv', 'typisk', 'arbejdsdag', 'ser', 'arthur', 'mød', 'kl', '730', 'morgenmød', 'slag', 'debriefing', 'chef', 'går', 'to', 'to', 'rum', 'sat', 'dag', 'alm', 'røntg', 'mrscan', 'start', 'regel', 'kop', 'kaf', 'dag', 'produktion', 'start', 'først', 'patient', 'book', '745', 'kør', 'hvert', 'fald', 'kl', '15', 'tag', 'hjem', 'glem', 'foregår', 'typisk', 'undersøg', 'når', 'samarbejd', 'patient', 'arthur', 'ned', 'mrscan', 'kræv', 'kontak', 'kommunikation', 'mrscanning', 'alm', 'røntgenundersøg', 'godt', 'scary', 'ubehag', 'patient', 'kom', 'rør', 'larm', 'når', 'går', 'handl', 'hurt', 'dan', 'kontak', 'patient', 'mød', 'patient', 'sig', 'bar', 'overstå', 'sig', 'prøv', 'sig', 'bang', 'lig', 'ej', 'helt', 'derind', 'mød', 'patient', 'sær', 'lang', 'tid', 'fem', 'minut', 'connect', 'patient', 'stol', 'lav', 'alarm', 'bold', 'osv', 'alm', 'røntg', 'stil', 'klik', 'klik', 'tryk', 'knap', 'tag', 'billed', 'får', 'svar', 'læg', 'kommunik', 'patient', 'får', 'ordent', 'billed', 'patient', 'eksempel', 'arm', 'strå', 'skråt', 'billed', 'jam', 'jen', 'kom', 'godt', 'led', 'ordent', 'osv', 'kommunikation', 'fyld', 'del', 'dår', 'kommunikation', 'får', 'dår', 'undersøg', 'får', 'patient', 'dår', 'behandling', 'dår', 'udredning', 'tag', 'tid', 'vigt', 'kontak', 'kommunikation', 'start', 'patient', 'mød', 'løb', 'typisk', 'arbejdsdag', 'arthur', 'mr', '8', '10', 'mrscanning', 'tag', 'regel', '4045', 'minut', 'alm', 'røntg', 'sagt', '30', ' ', '35', 'patient', 'dag', 'forstå', 'når', 'arbejdsdag', 'dedik', 'mr', 'arthur', 'ja', 'mød', 'morgen', 'find', 'hvilk', 'rum', 'sat', 'dag', 'fordel', 'først', 'sal', '2', 'ned', 'akut', 'afdeling', 'dag', 'sid', 'mrscanning', '1', 'sal', 'dag', '12', 'patient', 'simon', 'mærk', 'forskel', 'når', 'går', 'alm', 'røntg', 'mr', 'når', 'kommunikation', 'ting', 'indstil', 'mht', 'kommunikation', 'arthur', 'indstil', 'mennesk', 'røntgenbilled', 'prøv', 'mr', 'teknisk', 'rum', 'ser', 'scary', 'patient', 'udspurg', 'metal', 'pacemak', 'krop', 'dybdegå', 'kontak', 'eksempel', 'patient', 'bosni', 'find', 'spørg', 'blev', 'skudt', 'engang', 'krig', 'tænk', 'modsat', 'røntg', 'vurd', ' ', 'patient', 'stå', 'stå', 'mr', 'ting', 'tænk', 'arbejd', 'svejsning', 'klaustrofobi', 'metal', 'indoper', 'kontrast', 'indsprøjt', 'patient', 'vej', 'svar', 'nej', 'nej', 'bar', 'læg', 'se', 'forskel', 'dybdegå', 'kontak', 'brug', 'kontak', 'bero', 'patient', 'fremfor', 'undersøg', 'fag', 'undersøg', 'arthur', 'altså', 'undersøg', 'patient', 'mød', 'hinand', 'øjenhøjd', 'mød', 'patient', 'føl', 'tryg', 'går', 'undersøg', 'lig', 'stil', 'får', 'god', 'billed', 'patient', 'føl', 'bang', 'start', 'snak', 'undersøg', 'sig', 'slemt', 'okay', 'nervøs', 'gang', 'undersøg', 'oplev', 'patient', 'hvilk', 'nem', 'undersøg', 'beskriv', 'patientkommunikation', 'ting', 'føl', 'patient', 'glad', 'oplev', ' ', 'arthur', ' ', ' ...

# %%
# Create an instance of the standalone lemmatizer (without POS (Parts of Speech))
lemmatizer = lemmy.load("da")
lemmatized_tokens = [lemmatizer.lemmatize("", token) for token in stemmed_tokens]

# %%
print(lemmatized_tokens)
# Out:
# [['regne', 'regn'], ['tagge', 'tage', 'tag'], ['cirka'], ['40'], ['minut'], ['plusse', 'plus'], ['minusse', 'minus'], ['afhænge'], ['få', 'får'], ['fylde', 'fyld'], ['opfølge'], ['spørgsmål'], ['tinge', 'ting'], ['bunde', 'bund'], ['grunde', 'grund'], ['bar', 'bare', 'bære'], ['godt', 'godte', 'god'], ['hør', 'høre'], ['din', 'dit'], ['arbejde'], ['kommunik'], ['patient'], ['start', 'starte'], ['godt', 'godte', 'god'], ['hør', 'høre'], ['fortælle'], ['få'], ['radiograf'], ['arthur'], ['jamme'], ['hedde', 'hed'], ['arthur'], ['32'], ['gange', 'gang'], ['24'], ['23'], ['vide'], ['hel', 'helt'], ['arbejde'], ['have'], ['lyste', 'lyse', 'lys', 'lyst'], ['arbejde'], ['mennesk'], ['sid', 'sidde'], ['kontor'], ['snakke', 'snak'], ['patient'], ['gamle'], ['mennesk'], ['bar', 'bare', 'bære'], ['kombination'], ['samtid'], ['gide', 'gad'], ['sygeplejersk'], ['teknologisk'], ['comput', 'computte'], ['åben'], ['hus', 'hu', 'huse'], ['uddanne'], ['tænke'], ['tja'], ['godt', 'godte', 'god'], ['fremtid'], ['prøved'], ['kende'], ['når', 'nå'], ['finde'], ['din', 'dit'], ['hulle', 'hul', 'hule'], ['samfund'], ['passed'], ['bar', 'bare', 'bære'], ['person'], ['teknologisk'], ['scanning'], ['spænd', 'spænde'], ['samtid'], ['patient'], ['sin'], ['histori'], ['tro'], ['ensarte'], ['arbejde'], ['patient'], ['anderled'], ['ensarte'], ['surre', 'sur'], ['glad'], ['bar', 'bare', 'bære'], ['normal'], ['få'], ['tænke'], ['okay'], ['lav', 'lave'], ['typ'], ['arbejde'], ['udfordring'], ['radiograf'], ['god'], ['opleve'], ['selvfølge'], ['lange', 'lang'], ['tid'], ['radiograf'], ['arthur'], ['6'], ['åre', 'år'], ['radiograf'], ['din', 'dit'], ['arbejdsområd'], ['arthur'], ['hedde', 'hed'], ['mrsuperbrug'], ['arbejde'], ['primært', 'primær'], ['mrscanne'], ['udlåne'], ['stede', 'sted'], ['behov'], ['uddanne'], ['hele', 'hel'], ['specialområd'], ['mre'], ['prøve'], ['beskrive'], ['typisk'], ['arbejdsdag'], ['se'], ['arthur'], ['møde'], ['klokke', 'kl'], ['730'], ['morgenmøde'], ['slagge', 'slag'], ['debriefing'], ['chef'], ['går', 'gå'], ['to'], ['to'], ['rumme', 'rum'], ['sat', 'sætte'], ['dag'], ['alme'], ['røntg'], ['mrscanne'], ['start', 'starte'], ['regel'], ['kop'], ['kaffe'], ['dag'], ['produktion'], ['start', 'starte'], ['først'], ['patient'], ['booke'], ['745'], ['køre'], ['hver'], ['falde', 'fald'], ['klokke', 'kl'], ['15'], ['tagge', 'tage', 'tag'], ['hjem'], ['glemme'], ['foregå'], ['typisk'], ['undersøge'], ['når', 'nå'], ['samarbejde'], ['patient'], ['arthur'], ['ned'], ['mrscanne'], ['kræve'], ['kontak', 'kontakke'], ['kommunikation'], ['mrscanning'], ['alme'], ['røntgenundersøge'], ['godt', 'godte', 'god'], ['scary'], ['ubehag'], ['patient'], ['komme'], ['rør', 'røre'], ['larm', 'larme'], ['når', 'nå'], ['går', 'gå'], ['handle'], ['hurt'], ['dan', 'danne'], ['kontak', 'kontakke'], ['patient'], ['møde'], ['patient'], ['sige', 'sig'], ['bar', 'bare', 'bære'], ['overstå'], ['sige', 'sig'], ['prøve'], ['sige', 'sig'], ['bang'], ['ligge', 'lig'], ['eje', 'ej'], ['hel', 'helt'], ['derind'], ['møde'], ['patient'], ['sær'], ['lange', 'lang'], ['tid'], ['fem'], ['minut'], ['connect'], ['patient'], ['stole', 'stol'], ['lav', 'lave'], ['alarm'], ['bold'], ['osv'], ['alme'], ['røntg'], ['stile', 'stille', 'stil'], ['klikke', 'klik'], ['klikke', 'klik'], ['trykke', 'tryk'], ['knappe', 'knap'], ['tagge', 'tage', 'tag'], ['billed'], ['få', 'får'], ['svar', 'svare'], ['læge', 'lægge', 'læg'], ['kommunik'], ['patient'], ['få', 'får'], ['ordent'], ['billed'], ['patient'], ['eksempel'], ['arm'], ['strå'], ['skrå', 'skråt'], ['billed'], ['jamme'], ['jen'], ['komme'], ['godt', 'godte', 'god'], ['led', 'lide', 'lede'], ['ordent'], ['osv'], ['kommunikation'], ['fylde', 'fyld'], ['del', 'dele'], ['dåre'], ['kommunikation'], ['få', 'får'], ['dåre'], ['undersøge'], ['få', 'får'], ['patient'], ['dåre'], ['behandling'], ['dåre'], ['udredning'], ['tagge', 'tage', 'tag'], ['tid'], ['vigte'], ['kontak', 'kontakke'], ['kommunikation'], ['start', 'starte'], ['patient'], ['mød ...

# %%
# We got 6800 tokens
number_of_elements = len(lemmatized_tokens)
print(number_of_elements)
# Out:
# 6767
